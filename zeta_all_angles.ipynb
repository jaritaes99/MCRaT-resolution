# %%
# %matplotlib notebook
import processmcrat as pm
import astropy.units as unit
from astropy import constants as const
import matplotlib.pyplot as plt
import numpy as np

'''
Plotting spectra and peak energies vs refinement level for final frame in spherical outflow simulation
'''
# Out:
# '\nPlotting spectra and peak energies vs refinement level for final frame in spherical outflow simulation\n'

# %%
mcrat_sim5_5=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/spatial-res-levs/final-conditions-res-levs/5/") 
mcrat_sim5_5.load_frame(2638, read_stokes=False)


mcrat_sim5_4=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/spatial-res-levs/final-conditions-res-levs/4/") 
mcrat_sim5_4.load_frame(2638, read_stokes=False)


mcrat_sim5_3=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/spatial-res-levs/final-conditions-res-levs/3/") 
mcrat_sim5_3.load_frame(2638, read_stokes=False)


mcrat_sim5_2=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/spatial-res-levs/final-conditions-res-levs/2/") 
mcrat_sim5_2.load_frame(2638, read_stokes=False)


mcrat_sim5_1=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/spatial-res-levs/final-conditions-res-levs/1/") 
mcrat_sim5_1.load_frame(2638, read_stokes=False)

mcrat_sim4_5=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/temporal-res-levs/final-conditions-res-levs/2.5fps/") 
mcrat_sim4_5.load_frame(1319, read_stokes=False)


mcrat_sim4_4=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/2.5fps-lev4/") 
mcrat_sim4_4.load_frame(1319, read_stokes=False)


mcrat_sim4_3=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/2.5fps-lev3/") 
mcrat_sim4_3.load_frame(1319, read_stokes=False)


mcrat_sim4_2=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/2.5fps-lev2/") 
mcrat_sim4_2.load_frame(1319, read_stokes=False)


mcrat_sim4_1=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/2.5fps-lev1/") 
mcrat_sim4_1.load_frame(1319, read_stokes=False)



mcrat_sim3_5=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/temporal-res-levs/final-conditions-res-levs/1.25fps/") 
mcrat_sim3_5.load_frame(659, read_stokes=False)


mcrat_sim3_4=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/1.25fps-lev4/") 
mcrat_sim3_4.load_frame(659, read_stokes=False)


mcrat_sim3_3=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/1.25fps-lev3/") 
mcrat_sim3_3.load_frame(659, read_stokes=False)


mcrat_sim3_2=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/1.25fps-lev2/") 
mcrat_sim3_2.load_frame(659, read_stokes=False)


mcrat_sim3_1=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/1.25fps-lev1/") 
mcrat_sim3_1.load_frame(659, read_stokes=False)


mcrat_sim2_5=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/temporal-res-levs/final-conditions-res-levs/0.625fps/") 
mcrat_sim2_5.load_frame(329, read_stokes=False)


mcrat_sim2_4=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.625fps-lev4/") 
mcrat_sim2_4.load_frame(329, read_stokes=False)


mcrat_sim2_3=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.625fps-lev3/") 
mcrat_sim2_3.load_frame(329, read_stokes=False)


mcrat_sim2_2=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.625fps-lev2/") 
mcrat_sim2_2.load_frame(329, read_stokes=False)


mcrat_sim2_1=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.625fps-lev1/") 
mcrat_sim2_1.load_frame(329, read_stokes=False)


mcrat_sim1_5=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/temporal-res-levs/final-conditions-res-levs/0.3125fps/") 
mcrat_sim1_5.load_frame(164, read_stokes=False)


mcrat_sim1_4=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.3125fps-lev4/") 
mcrat_sim1_4.load_frame(164, read_stokes=False)


mcrat_sim1_3=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.3125fps-lev3/") 
mcrat_sim1_3.load_frame(164, read_stokes=False)

mcrat_sim1_2=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.3125fps-lev2/") 
mcrat_sim1_2.load_frame(164, read_stokes=False)


mcrat_sim1_1=pm.McratSimLoad(
    "/Users/josearita-escalante/Documents/GRB-NASA/MCRaT-gits/MCRaT-resolution/CHOMBO/science/3000-8000-photons/mixed-res-levs/final-conditions-res-levs/0.3125fps-lev1/") 
mcrat_sim1_1.load_frame(164, read_stokes=False)

# %%
observation_th1_5_5=pm.MockObservation(1, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_5)
observation_th1_5_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_5_4=pm.MockObservation(1, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_4)
observation_th1_5_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_5_3=pm.MockObservation(1, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_3)
observation_th1_5_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_5_2=pm.MockObservation(1, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_2)
observation_th1_5_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_5_1=pm.MockObservation(1, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_1)
observation_th1_5_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_4_5=pm.MockObservation(1, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_5)
observation_th1_4_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_4_4=pm.MockObservation(1, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_4)
observation_th1_4_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_4_3=pm.MockObservation(1, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_3)
observation_th1_4_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_4_2=pm.MockObservation(1, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_2)
observation_th1_4_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_4_1=pm.MockObservation(1, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_1)
observation_th1_4_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_3_5=pm.MockObservation(1, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_5)
observation_th1_3_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_3_4=pm.MockObservation(1, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_4)
observation_th1_3_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_3_3=pm.MockObservation(1, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_3)
observation_th1_3_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_3_2=pm.MockObservation(1, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_2)
observation_th1_3_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_3_1=pm.MockObservation(1, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_1)
observation_th1_3_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_2_5=pm.MockObservation(1, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_5)
observation_th1_2_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_2_4=pm.MockObservation(1, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_4)
observation_th1_2_4.set_spectral_fit_parameters(spectral_fit_energy_range=[2.4, 40000.0])


observation_th1_2_3=pm.MockObservation(1, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_3)
observation_th1_2_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_2_2=pm.MockObservation(1, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_2)
observation_th1_2_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_2_1=pm.MockObservation(1, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_1)
observation_th1_2_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_1_5=pm.MockObservation(1, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_5)
observation_th1_1_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_1_4=pm.MockObservation(1, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_4)
observation_th1_1_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_1_3=pm.MockObservation(1, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_3)
observation_th1_1_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_1_2=pm.MockObservation(1, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_2)
observation_th1_1_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th1_1_1=pm.MockObservation(1, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_1)
observation_th1_1_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])

# %%
observation_th3_5_5=pm.MockObservation(3, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_5)
observation_th3_5_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_5_4=pm.MockObservation(3, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_4)
observation_th3_5_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_5_3=pm.MockObservation(3, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_3)
observation_th3_5_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_5_2=pm.MockObservation(3, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_2)
observation_th3_5_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_5_1=pm.MockObservation(3, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_1)
observation_th3_5_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_4_5=pm.MockObservation(3, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_5)
observation_th3_4_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_4_4=pm.MockObservation(3, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_4)
observation_th3_4_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_4_3=pm.MockObservation(3, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_3)
observation_th3_4_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_4_2=pm.MockObservation(3, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_2)
observation_th3_4_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_4_1=pm.MockObservation(3, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_1)
observation_th3_4_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_3_5=pm.MockObservation(3, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_5)
observation_th3_3_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_3_4=pm.MockObservation(3, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_4)
observation_th3_3_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_3_3=pm.MockObservation(3, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_3)
observation_th3_3_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_3_2=pm.MockObservation(3, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_2)
observation_th3_3_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_3_1=pm.MockObservation(3, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_1)
observation_th3_3_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_2_5=pm.MockObservation(3, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_5)
observation_th3_2_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_2_4=pm.MockObservation(3, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_4)
observation_th3_2_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_2_3=pm.MockObservation(3, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_3)
observation_th3_2_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_2_2=pm.MockObservation(3, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_2)
observation_th3_2_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_2_1=pm.MockObservation(3, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_1)
observation_th3_2_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_1_5=pm.MockObservation(3, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_5)
observation_th3_1_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_1_4=pm.MockObservation(3, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_4)
observation_th3_1_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_1_3=pm.MockObservation(3, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_3)
observation_th3_1_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_1_2=pm.MockObservation(3, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_2)
observation_th3_1_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th3_1_1=pm.MockObservation(3, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_1)
observation_th3_1_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])

# %%
observation_th5_5_5=pm.MockObservation(5, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_5)
observation_th5_5_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_5_4=pm.MockObservation(5, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_4)
observation_th5_5_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_5_3=pm.MockObservation(5, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_3)
observation_th5_5_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_5_2=pm.MockObservation(5, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_2)
observation_th5_5_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_5_1=pm.MockObservation(5, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_1)
observation_th5_5_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_4_5=pm.MockObservation(5, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_5)
observation_th5_4_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_4_4=pm.MockObservation(5, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_4)
observation_th5_4_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_4_3=pm.MockObservation(5, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_3)
observation_th5_4_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_4_2=pm.MockObservation(5, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_2)
observation_th5_4_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_4_1=pm.MockObservation(5, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_1)
observation_th5_4_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_3_5=pm.MockObservation(5, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_5)
observation_th5_3_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_3_4=pm.MockObservation(5, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_4)
observation_th5_3_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_3_3=pm.MockObservation(5, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_3)
observation_th5_3_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_3_2=pm.MockObservation(5, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_2)
observation_th5_3_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_3_1=pm.MockObservation(5, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_1)
observation_th5_3_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_2_5=pm.MockObservation(5, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_5)
observation_th5_2_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_2_4=pm.MockObservation(5, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_4)
observation_th5_2_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_2_3=pm.MockObservation(5, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_3)
observation_th5_2_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_2_2=pm.MockObservation(5, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_2)
observation_th5_2_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_2_1=pm.MockObservation(5, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_1)
observation_th5_2_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_1_5=pm.MockObservation(5, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_5)
observation_th5_1_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_1_4=pm.MockObservation(5, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_4)
observation_th5_1_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_1_3=pm.MockObservation(5, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_3)
observation_th5_1_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_1_2=pm.MockObservation(5, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_2)
observation_th5_1_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th5_1_1=pm.MockObservation(5, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_1)
observation_th5_1_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])

# %%
observation_th8_5_5=pm.MockObservation(8, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_5)
observation_th8_5_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_5_4=pm.MockObservation(8, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_4)
observation_th8_5_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_5_3=pm.MockObservation(8, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_3)
observation_th8_5_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_5_2=pm.MockObservation(8, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_2)
observation_th8_5_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_5_1=pm.MockObservation(8, 4, 1e14, 5, mcratsimload_obj=mcrat_sim5_1)
observation_th8_5_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_4_5=pm.MockObservation(8, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_5)
observation_th8_4_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_4_4=pm.MockObservation(8, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_4)
observation_th8_4_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_4_3=pm.MockObservation(8, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_3)
observation_th8_4_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_4_2=pm.MockObservation(8, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_2)
observation_th8_4_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_4_1=pm.MockObservation(8, 4, 1e14, 2.5, mcratsimload_obj=mcrat_sim4_1)
observation_th8_4_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_3_5=pm.MockObservation(8, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_5)
observation_th8_3_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_3_4=pm.MockObservation(8, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_4)
observation_th8_3_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_3_3=pm.MockObservation(8, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_3)
observation_th8_3_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_3_2=pm.MockObservation(8, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_2)
observation_th8_3_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_3_1=pm.MockObservation(8, 4, 1e14, 1.25, mcratsimload_obj=mcrat_sim3_1)
observation_th8_3_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_2_5=pm.MockObservation(8, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_5)
observation_th8_2_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_2_4=pm.MockObservation(8, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_4)
observation_th8_2_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_2_3=pm.MockObservation(8, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_3)
observation_th8_2_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_2_2=pm.MockObservation(8, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_2)
observation_th8_2_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_2_1=pm.MockObservation(8, 4, 1e14, 0.625, mcratsimload_obj=mcrat_sim2_1)
observation_th8_2_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_1_5=pm.MockObservation(8, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_5)
observation_th8_1_5.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_1_4=pm.MockObservation(8, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_4)
observation_th8_1_4.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_1_3=pm.MockObservation(8, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_3)
observation_th8_1_3.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_1_2=pm.MockObservation(8, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_2)
observation_th8_1_2.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])


observation_th8_1_1=pm.MockObservation(8, 4, 1e14, 0.3125, mcratsimload_obj=mcrat_sim1_1)
observation_th8_1_1.set_spectral_fit_parameters(spectral_fit_energy_range=[0.01, 40000.0])

# %%
unfitted_spectrum_dict_th1_5_5=observation_th1_5_5.spectrum(observation_th1_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_5_4=observation_th1_5_4.spectrum(observation_th1_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_5_3=observation_th1_5_3.spectrum(observation_th1_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_5_2=observation_th1_5_2.spectrum(observation_th1_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_5_1=observation_th1_5_1.spectrum(observation_th1_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_4_5=observation_th1_4_5.spectrum(observation_th1_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_4_4=observation_th1_4_4.spectrum(observation_th1_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_4_3=observation_th1_4_3.spectrum(observation_th1_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_4_2=observation_th1_4_2.spectrum(observation_th1_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_4_1=observation_th1_4_1.spectrum(observation_th1_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_3_5=observation_th1_3_5.spectrum(observation_th1_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_3_4=observation_th1_3_4.spectrum(observation_th1_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_3_3=observation_th1_3_3.spectrum(observation_th1_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_3_2=observation_th1_3_2.spectrum(observation_th1_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_3_1=observation_th1_3_1.spectrum(observation_th1_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_2_5=observation_th1_2_5.spectrum(observation_th1_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_2_4=observation_th1_2_4.spectrum(observation_th1_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_2_3=observation_th1_2_3.spectrum(observation_th1_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_2_2=observation_th1_2_2.spectrum(observation_th1_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_2_1=observation_th1_2_1.spectrum(observation_th1_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_1_5=observation_th1_1_5.spectrum(observation_th1_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_1_4=observation_th1_1_4.spectrum(observation_th1_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_1_3=observation_th1_1_3.spectrum(observation_th1_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_1_2=observation_th1_1_2.spectrum(observation_th1_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th1_1_1=observation_th1_1_1.spectrum(observation_th1_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_1.detected_photons.detection_time.max()+1)

# %%
unfitted_spectrum_dict_th3_5_5=observation_th3_5_5.spectrum(observation_th3_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_5_4=observation_th3_5_4.spectrum(observation_th3_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_5_3=observation_th3_5_3.spectrum(observation_th3_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_5_2=observation_th3_5_2.spectrum(observation_th3_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_5_1=observation_th3_5_1.spectrum(observation_th3_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_4_5=observation_th3_4_5.spectrum(observation_th3_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_4_4=observation_th3_4_4.spectrum(observation_th3_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_4_3=observation_th3_4_3.spectrum(observation_th3_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_4_2=observation_th3_4_2.spectrum(observation_th3_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_4_1=observation_th3_4_1.spectrum(observation_th3_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_3_5=observation_th3_3_5.spectrum(observation_th3_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_3_4=observation_th3_3_4.spectrum(observation_th3_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_3_3=observation_th3_3_3.spectrum(observation_th3_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_3_2=observation_th3_3_2.spectrum(observation_th3_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_3_1=observation_th3_3_1.spectrum(observation_th3_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_2_5=observation_th3_2_5.spectrum(observation_th3_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_2_4=observation_th3_2_4.spectrum(observation_th3_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_2_3=observation_th3_2_3.spectrum(observation_th3_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_2_2=observation_th3_2_2.spectrum(observation_th3_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_2_1=observation_th3_2_1.spectrum(observation_th3_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_1_5=observation_th3_1_5.spectrum(observation_th3_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_1_4=observation_th3_1_4.spectrum(observation_th3_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_1_3=observation_th3_1_3.spectrum(observation_th3_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_1_2=observation_th3_1_2.spectrum(observation_th3_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th3_1_1=observation_th3_1_1.spectrum(observation_th3_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_1.detected_photons.detection_time.max()+1)

# %%
unfitted_spectrum_dict_th5_5_5=observation_th5_5_5.spectrum(observation_th5_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_5_4=observation_th5_5_4.spectrum(observation_th5_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_5_3=observation_th5_5_3.spectrum(observation_th5_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_5_2=observation_th5_5_2.spectrum(observation_th5_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_5_1=observation_th5_5_1.spectrum(observation_th5_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_4_5=observation_th5_4_5.spectrum(observation_th5_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_4_4=observation_th5_4_4.spectrum(observation_th5_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_4_3=observation_th5_4_3.spectrum(observation_th5_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_4_2=observation_th5_4_2.spectrum(observation_th5_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_4_1=observation_th5_4_1.spectrum(observation_th5_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_3_5=observation_th5_3_5.spectrum(observation_th5_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_3_4=observation_th5_3_4.spectrum(observation_th5_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_3_3=observation_th5_3_3.spectrum(observation_th5_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_3_2=observation_th5_3_2.spectrum(observation_th5_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_3_1=observation_th5_3_1.spectrum(observation_th5_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_2_5=observation_th5_2_5.spectrum(observation_th5_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_2_4=observation_th5_2_4.spectrum(observation_th5_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_2_3=observation_th5_2_3.spectrum(observation_th5_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_2_2=observation_th5_2_2.spectrum(observation_th5_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_2_1=observation_th5_2_1.spectrum(observation_th5_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_1_5=observation_th5_1_5.spectrum(observation_th5_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_1_4=observation_th5_1_4.spectrum(observation_th5_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_1_3=observation_th5_1_3.spectrum(observation_th5_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_1_2=observation_th5_1_2.spectrum(observation_th5_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th5_1_1=observation_th5_1_1.spectrum(observation_th5_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_1.detected_photons.detection_time.max()+1)

# %%
unfitted_spectrum_dict_th8_5_5=observation_th8_5_5.spectrum(observation_th8_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_5_4=observation_th8_5_4.spectrum(observation_th8_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_5_3=observation_th8_5_3.spectrum(observation_th8_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_5_2=observation_th8_5_2.spectrum(observation_th8_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_5_1=observation_th8_5_1.spectrum(observation_th8_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_4_5=observation_th8_4_5.spectrum(observation_th8_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_4_4=observation_th8_4_4.spectrum(observation_th8_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_4_3=observation_th8_4_3.spectrum(observation_th8_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_4_2=observation_th8_4_2.spectrum(observation_th8_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_4_1=observation_th8_4_1.spectrum(observation_th8_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_3_5=observation_th8_3_5.spectrum(observation_th8_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_3_4=observation_th8_3_4.spectrum(observation_th8_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_3_3=observation_th8_3_3.spectrum(observation_th8_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_3_2=observation_th8_3_2.spectrum(observation_th8_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_3_1=observation_th8_3_1.spectrum(observation_th8_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_2_5=observation_th8_2_5.spectrum(observation_th8_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_2_4=observation_th8_2_4.spectrum(observation_th8_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_2_3=observation_th8_2_3.spectrum(observation_th8_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_2_2=observation_th8_2_2.spectrum(observation_th8_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_2_1=observation_th8_2_1.spectrum(observation_th8_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_1.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_1_5=observation_th8_1_5.spectrum(observation_th8_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_5.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_1_4=observation_th8_1_4.spectrum(observation_th8_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_4.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_1_3=observation_th8_1_3.spectrum(observation_th8_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_3.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_1_2=observation_th8_1_2.spectrum(observation_th8_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_2.detected_photons.detection_time.max()+1)

unfitted_spectrum_dict_th8_1_1=observation_th8_1_1.spectrum(observation_th8_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_1.detected_photons.detection_time.max()+1)

# %%
fitted_spectrum_dict_th1_5_5=observation_th1_5_5.spectrum(observation_th1_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_5.detected_photons.detection_time.max()+1,                                      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                            
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_5_4=observation_th1_5_4.spectrum(observation_th1_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_4.detected_photons.detection_time.max()+1, 
                                     spectrum_unit=unit.count/unit.s/unit.keV,   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_5_3=observation_th1_5_3.spectrum(observation_th1_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_3.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,         
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_5_2=observation_th1_5_2.spectrum(observation_th1_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_2.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_5_1=observation_th1_5_1.spectrum(observation_th1_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_5_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_4_5=observation_th1_4_5.spectrum(observation_th1_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_5.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,               
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_4_4=observation_th1_4_4.spectrum(observation_th1_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_4.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_4_3=observation_th1_4_3.spectrum(observation_th1_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_4_2=observation_th1_4_2.spectrum(observation_th1_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_2.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_4_1=observation_th1_4_1.spectrum(observation_th1_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_4_1.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_3_5=observation_th1_3_5.spectrum(observation_th1_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_5.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_3_4=observation_th1_3_4.spectrum(observation_th1_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_4.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                  
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_3_3=observation_th1_3_3.spectrum(observation_th1_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_3.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                       
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_3_2=observation_th1_3_2.spectrum(observation_th1_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_2.detected_photons.detection_time.max()+1,        
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_3_1=observation_th1_3_1.spectrum(observation_th1_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_3_1.detected_photons.detection_time.max()+1,          
                                     spectrum_unit=unit.count/unit.s/unit.keV,                           
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_2_5=observation_th1_2_5.spectrum(observation_th1_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_5.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_2_4=observation_th1_2_4.spectrum(observation_th1_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_4.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_2_3=observation_th1_2_3.spectrum(observation_th1_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_2_2=observation_th1_2_2.spectrum(observation_th1_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_2.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_2_1=observation_th1_2_1.spectrum(observation_th1_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_2_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_1_5=observation_th1_1_5.spectrum(observation_th1_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_5.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_1_4=observation_th1_1_4.spectrum(observation_th1_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_4.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_1_3=observation_th1_1_3.spectrum(observation_th1_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                      
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_1_2=observation_th1_1_2.spectrum(observation_th1_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_2.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th1_1_1=observation_th1_1_1.spectrum(observation_th1_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th1_1_1.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)
# Out:
# /Users/josearita-escalante/opt/anaconda3/lib/python3.8/site-packages/processmcrat/mclib.py:41: RuntimeWarning: invalid value encountered in double_scalars
#   model[kk]=((alpha-beta)*break_energy)**(alpha-beta)*energies[kk]**(beta)*np.exp(beta-alpha)

# %%
fitted_spectrum_dict_th3_5_5=observation_th3_5_5.spectrum(observation_th3_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_5.detected_photons.detection_time.max()+1,                                      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                            
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_5_4=observation_th3_5_4.spectrum(observation_th3_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_4.detected_photons.detection_time.max()+1, 
                                     spectrum_unit=unit.count/unit.s/unit.keV,   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_5_3=observation_th3_5_3.spectrum(observation_th3_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_3.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,         
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_5_2=observation_th3_5_2.spectrum(observation_th3_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_2.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_5_1=observation_th3_5_1.spectrum(observation_th3_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_5_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_4_5=observation_th3_4_5.spectrum(observation_th3_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_5.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,               
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_4_4=observation_th3_4_4.spectrum(observation_th3_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_4.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_4_3=observation_th3_4_3.spectrum(observation_th3_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_4_2=observation_th3_4_2.spectrum(observation_th3_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_2.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_4_1=observation_th3_4_1.spectrum(observation_th3_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_4_1.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_3_5=observation_th3_3_5.spectrum(observation_th3_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_5.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_3_4=observation_th3_3_4.spectrum(observation_th3_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_4.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                  
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_3_3=observation_th3_3_3.spectrum(observation_th3_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_3.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                       
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_3_2=observation_th3_3_2.spectrum(observation_th3_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_2.detected_photons.detection_time.max()+1,        
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_3_1=observation_th3_3_1.spectrum(observation_th3_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_3_1.detected_photons.detection_time.max()+1,          
                                     spectrum_unit=unit.count/unit.s/unit.keV,                           
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_2_5=observation_th3_2_5.spectrum(observation_th3_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_5.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_2_4=observation_th3_2_4.spectrum(observation_th3_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_4.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_2_3=observation_th3_2_3.spectrum(observation_th3_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_2_2=observation_th3_2_2.spectrum(observation_th3_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_2.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_2_1=observation_th3_2_1.spectrum(observation_th3_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_2_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_1_5=observation_th3_1_5.spectrum(observation_th3_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_5.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_1_4=observation_th3_1_4.spectrum(observation_th3_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_4.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_1_3=observation_th3_1_3.spectrum(observation_th3_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                      
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_1_2=observation_th3_1_2.spectrum(observation_th3_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_2.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th3_1_1=observation_th3_1_1.spectrum(observation_th3_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th3_1_1.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

# %%
fitted_spectrum_dict_th5_5_5=observation_th5_5_5.spectrum(observation_th5_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_5.detected_photons.detection_time.max()+1,                                      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                            
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_5_4=observation_th5_5_4.spectrum(observation_th5_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_4.detected_photons.detection_time.max()+1, 
                                     spectrum_unit=unit.count/unit.s/unit.keV,   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_5_3=observation_th5_5_3.spectrum(observation_th5_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_3.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,         
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_5_2=observation_th5_5_2.spectrum(observation_th5_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_2.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_5_1=observation_th5_5_1.spectrum(observation_th5_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_5_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_4_5=observation_th5_4_5.spectrum(observation_th5_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_5.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,               
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_4_4=observation_th5_4_4.spectrum(observation_th5_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_4.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_4_3=observation_th5_4_3.spectrum(observation_th5_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_4_2=observation_th5_4_2.spectrum(observation_th5_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_2.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_4_1=observation_th5_4_1.spectrum(observation_th5_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_4_1.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_3_5=observation_th5_3_5.spectrum(observation_th5_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_5.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_3_4=observation_th5_3_4.spectrum(observation_th5_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_4.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                  
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_3_3=observation_th5_3_3.spectrum(observation_th5_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_3.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                       
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_3_2=observation_th5_3_2.spectrum(observation_th5_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_2.detected_photons.detection_time.max()+1,        
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_3_1=observation_th5_3_1.spectrum(observation_th5_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_3_1.detected_photons.detection_time.max()+1,          
                                     spectrum_unit=unit.count/unit.s/unit.keV,                           
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_2_5=observation_th5_2_5.spectrum(observation_th5_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_5.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_2_4=observation_th5_2_4.spectrum(observation_th5_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_4.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_2_3=observation_th5_2_3.spectrum(observation_th5_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_2_2=observation_th5_2_2.spectrum(observation_th5_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_2.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_2_1=observation_th5_2_1.spectrum(observation_th5_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_2_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_1_5=observation_th5_1_5.spectrum(observation_th5_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_5.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_1_4=observation_th5_1_4.spectrum(observation_th5_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_4.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_1_3=observation_th5_1_3.spectrum(observation_th5_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                      
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_1_2=observation_th5_1_2.spectrum(observation_th5_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_2.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th5_1_1=observation_th5_1_1.spectrum(observation_th5_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th5_1_1.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

# %%
fitted_spectrum_dict_th8_5_5=observation_th8_5_5.spectrum(observation_th8_5_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_5.detected_photons.detection_time.max()+1,                                      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                            
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_5_4=observation_th8_5_4.spectrum(observation_th8_5_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_4.detected_photons.detection_time.max()+1, 
                                     spectrum_unit=unit.count/unit.s/unit.keV,   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_5_3=observation_th8_5_3.spectrum(observation_th8_5_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_3.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,         
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_5_2=observation_th8_5_2.spectrum(observation_th8_5_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_2.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_5_1=observation_th8_5_1.spectrum(observation_th8_5_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_5_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_4_5=observation_th8_4_5.spectrum(observation_th8_4_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_5.detected_photons.detection_time.max()+1,            
                                     spectrum_unit=unit.count/unit.s/unit.keV,               
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_4_4=observation_th8_4_4.spectrum(observation_th8_4_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_4.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_4_3=observation_th8_4_3.spectrum(observation_th8_4_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_4_2=observation_th8_4_2.spectrum(observation_th8_4_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_2.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_4_1=observation_th8_4_1.spectrum(observation_th8_4_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_4_1.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_3_5=observation_th8_3_5.spectrum(observation_th8_3_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_5.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_3_4=observation_th8_3_4.spectrum(observation_th8_3_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_4.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                  
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_3_3=observation_th8_3_3.spectrum(observation_th8_3_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_3.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                       
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_3_2=observation_th8_3_2.spectrum(observation_th8_3_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_2.detected_photons.detection_time.max()+1,        
                                     spectrum_unit=unit.count/unit.s/unit.keV,                          
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_3_1=observation_th8_3_1.spectrum(observation_th8_3_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_3_1.detected_photons.detection_time.max()+1,          
                                     spectrum_unit=unit.count/unit.s/unit.keV,                           
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_2_5=observation_th8_2_5.spectrum(observation_th8_2_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_5.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_2_4=observation_th8_2_4.spectrum(observation_th8_2_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_4.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_2_3=observation_th8_2_3.spectrum(observation_th8_2_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_2_2=observation_th8_2_2.spectrum(observation_th8_2_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_2.detected_photons.detection_time.max()+1,   
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_2_1=observation_th8_2_1.spectrum(observation_th8_2_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_2_1.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_1_5=observation_th8_1_5.spectrum(observation_th8_1_5.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_5.detected_photons.detection_time.max()+1,    
                                     spectrum_unit=unit.count/unit.s/unit.keV,                    
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_1_4=observation_th8_1_4.spectrum(observation_th8_1_4.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_4.detected_photons.detection_time.max()+1,     
                                     spectrum_unit=unit.count/unit.s/unit.keV,                   
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_1_3=observation_th8_1_3.spectrum(observation_th8_1_3.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_3.detected_photons.detection_time.max()+1,      
                                     spectrum_unit=unit.count/unit.s/unit.keV,                      
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_1_2=observation_th8_1_2.spectrum(observation_th8_1_2.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_2.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                        
                                     fit_spectrum=True,sample_num=1e4)

fitted_spectrum_dict_th8_1_1=observation_th8_1_1.spectrum(observation_th8_1_1.detected_photons.detection_time.min()-1, 
                                     observation_th8_1_1.detected_photons.detection_time.max()+1,       
                                     spectrum_unit=unit.count/unit.s/unit.keV,                     
                                     fit_spectrum=True,sample_num=1e4)

# %%
unfitted_spectrum_dict_th1_arr = [[0 for x in range(5)] for y in range(5)]

unfitted_spectrum_dict_th1_arr[4][4] = unfitted_spectrum_dict_th1_5_5

unfitted_spectrum_dict_th1_arr[4][3] = unfitted_spectrum_dict_th1_5_4

unfitted_spectrum_dict_th1_arr[4][2] = unfitted_spectrum_dict_th1_5_3

unfitted_spectrum_dict_th1_arr[4][1] = unfitted_spectrum_dict_th1_5_2

unfitted_spectrum_dict_th1_arr[4][0] = unfitted_spectrum_dict_th1_5_1

unfitted_spectrum_dict_th1_arr[3][4] = unfitted_spectrum_dict_th1_4_5

unfitted_spectrum_dict_th1_arr[3][3] = unfitted_spectrum_dict_th1_4_4

unfitted_spectrum_dict_th1_arr[3][2] = unfitted_spectrum_dict_th1_4_3

unfitted_spectrum_dict_th1_arr[3][1] = unfitted_spectrum_dict_th1_4_2

unfitted_spectrum_dict_th1_arr[3][0] = unfitted_spectrum_dict_th1_4_1

unfitted_spectrum_dict_th1_arr[2][4] = unfitted_spectrum_dict_th1_3_5

unfitted_spectrum_dict_th1_arr[2][3] = unfitted_spectrum_dict_th1_3_4

unfitted_spectrum_dict_th1_arr[2][2] = unfitted_spectrum_dict_th1_3_3

unfitted_spectrum_dict_th1_arr[2][1] = unfitted_spectrum_dict_th1_3_2

unfitted_spectrum_dict_th1_arr[2][0] = unfitted_spectrum_dict_th1_3_1

unfitted_spectrum_dict_th1_arr[1][4] = unfitted_spectrum_dict_th1_2_5

unfitted_spectrum_dict_th1_arr[1][3] = unfitted_spectrum_dict_th1_2_4

unfitted_spectrum_dict_th1_arr[1][2] = unfitted_spectrum_dict_th1_2_3

unfitted_spectrum_dict_th1_arr[1][1] = unfitted_spectrum_dict_th1_2_2

unfitted_spectrum_dict_th1_arr[1][0] = unfitted_spectrum_dict_th1_2_1

unfitted_spectrum_dict_th1_arr[0][4] = unfitted_spectrum_dict_th1_1_5

unfitted_spectrum_dict_th1_arr[0][3] = unfitted_spectrum_dict_th1_1_4

unfitted_spectrum_dict_th1_arr[0][2] = unfitted_spectrum_dict_th1_1_3

unfitted_spectrum_dict_th1_arr[0][1] = unfitted_spectrum_dict_th1_1_2

unfitted_spectrum_dict_th1_arr[0][0] = unfitted_spectrum_dict_th1_1_1

# %%
unfitted_spectrum_dict_th3_arr = [[0 for x in range(5)] for y in range(5)]

unfitted_spectrum_dict_th3_arr[4][4] = unfitted_spectrum_dict_th3_5_5

unfitted_spectrum_dict_th3_arr[4][3] = unfitted_spectrum_dict_th3_5_4

unfitted_spectrum_dict_th3_arr[4][2] = unfitted_spectrum_dict_th3_5_3

unfitted_spectrum_dict_th3_arr[4][1] = unfitted_spectrum_dict_th3_5_2

unfitted_spectrum_dict_th3_arr[4][0] = unfitted_spectrum_dict_th3_5_1

unfitted_spectrum_dict_th3_arr[3][4] = unfitted_spectrum_dict_th3_4_5

unfitted_spectrum_dict_th3_arr[3][3] = unfitted_spectrum_dict_th3_4_4

unfitted_spectrum_dict_th3_arr[3][2] = unfitted_spectrum_dict_th3_4_3

unfitted_spectrum_dict_th3_arr[3][1] = unfitted_spectrum_dict_th3_4_2

unfitted_spectrum_dict_th3_arr[3][0] = unfitted_spectrum_dict_th3_4_1

unfitted_spectrum_dict_th3_arr[2][4] = unfitted_spectrum_dict_th3_3_5

unfitted_spectrum_dict_th3_arr[2][3] = unfitted_spectrum_dict_th3_3_4

unfitted_spectrum_dict_th3_arr[2][2] = unfitted_spectrum_dict_th3_3_3

unfitted_spectrum_dict_th3_arr[2][1] = unfitted_spectrum_dict_th3_3_2

unfitted_spectrum_dict_th3_arr[2][0] = unfitted_spectrum_dict_th3_3_1

unfitted_spectrum_dict_th3_arr[1][4] = unfitted_spectrum_dict_th3_2_5

unfitted_spectrum_dict_th3_arr[1][3] = unfitted_spectrum_dict_th3_2_4

unfitted_spectrum_dict_th3_arr[1][2] = unfitted_spectrum_dict_th3_2_3

unfitted_spectrum_dict_th3_arr[1][1] = unfitted_spectrum_dict_th3_2_2

unfitted_spectrum_dict_th3_arr[1][0] = unfitted_spectrum_dict_th3_2_1

unfitted_spectrum_dict_th3_arr[0][4] = unfitted_spectrum_dict_th3_1_5

unfitted_spectrum_dict_th3_arr[0][3] = unfitted_spectrum_dict_th3_1_4

unfitted_spectrum_dict_th3_arr[0][2] = unfitted_spectrum_dict_th3_1_3

unfitted_spectrum_dict_th3_arr[0][1] = unfitted_spectrum_dict_th3_1_2

unfitted_spectrum_dict_th3_arr[0][0] = unfitted_spectrum_dict_th3_1_1

# %%
unfitted_spectrum_dict_th5_arr = [[0 for x in range(5)] for y in range(5)]

unfitted_spectrum_dict_th5_arr[4][4] = unfitted_spectrum_dict_th5_5_5

unfitted_spectrum_dict_th5_arr[4][3] = unfitted_spectrum_dict_th5_5_4

unfitted_spectrum_dict_th5_arr[4][2] = unfitted_spectrum_dict_th5_5_3

unfitted_spectrum_dict_th5_arr[4][1] = unfitted_spectrum_dict_th5_5_2

unfitted_spectrum_dict_th5_arr[4][0] = unfitted_spectrum_dict_th5_5_1

unfitted_spectrum_dict_th5_arr[3][4] = unfitted_spectrum_dict_th5_4_5

unfitted_spectrum_dict_th5_arr[3][3] = unfitted_spectrum_dict_th5_4_4

unfitted_spectrum_dict_th5_arr[3][2] = unfitted_spectrum_dict_th5_4_3

unfitted_spectrum_dict_th5_arr[3][1] = unfitted_spectrum_dict_th5_4_2

unfitted_spectrum_dict_th5_arr[3][0] = unfitted_spectrum_dict_th5_4_1

unfitted_spectrum_dict_th5_arr[2][4] = unfitted_spectrum_dict_th5_3_5

unfitted_spectrum_dict_th5_arr[2][3] = unfitted_spectrum_dict_th5_3_4

unfitted_spectrum_dict_th5_arr[2][2] = unfitted_spectrum_dict_th5_3_3

unfitted_spectrum_dict_th5_arr[2][1] = unfitted_spectrum_dict_th5_3_2

unfitted_spectrum_dict_th5_arr[2][0] = unfitted_spectrum_dict_th5_3_1

unfitted_spectrum_dict_th5_arr[1][4] = unfitted_spectrum_dict_th5_2_5

unfitted_spectrum_dict_th5_arr[1][3] = unfitted_spectrum_dict_th5_2_4

unfitted_spectrum_dict_th5_arr[1][2] = unfitted_spectrum_dict_th5_2_3

unfitted_spectrum_dict_th5_arr[1][1] = unfitted_spectrum_dict_th5_2_2

unfitted_spectrum_dict_th5_arr[1][0] = unfitted_spectrum_dict_th5_2_1

unfitted_spectrum_dict_th5_arr[0][4] = unfitted_spectrum_dict_th5_1_5

unfitted_spectrum_dict_th5_arr[0][3] = unfitted_spectrum_dict_th5_1_4

unfitted_spectrum_dict_th5_arr[0][2] = unfitted_spectrum_dict_th5_1_3

unfitted_spectrum_dict_th5_arr[0][1] = unfitted_spectrum_dict_th5_1_2

unfitted_spectrum_dict_th5_arr[0][0] = unfitted_spectrum_dict_th5_1_1

# %%
unfitted_spectrum_dict_th8_arr = [[0 for x in range(5)] for y in range(5)]

unfitted_spectrum_dict_th8_arr[4][4] = unfitted_spectrum_dict_th8_5_5

unfitted_spectrum_dict_th8_arr[4][3] = unfitted_spectrum_dict_th8_5_4

unfitted_spectrum_dict_th8_arr[4][2] = unfitted_spectrum_dict_th8_5_3

unfitted_spectrum_dict_th8_arr[4][1] = unfitted_spectrum_dict_th8_5_2

unfitted_spectrum_dict_th8_arr[4][0] = unfitted_spectrum_dict_th8_5_1

unfitted_spectrum_dict_th8_arr[3][4] = unfitted_spectrum_dict_th8_4_5

unfitted_spectrum_dict_th8_arr[3][3] = unfitted_spectrum_dict_th8_4_4

unfitted_spectrum_dict_th8_arr[3][2] = unfitted_spectrum_dict_th8_4_3

unfitted_spectrum_dict_th8_arr[3][1] = unfitted_spectrum_dict_th8_4_2

unfitted_spectrum_dict_th8_arr[3][0] = unfitted_spectrum_dict_th8_4_1

unfitted_spectrum_dict_th8_arr[2][4] = unfitted_spectrum_dict_th8_3_5

unfitted_spectrum_dict_th8_arr[2][3] = unfitted_spectrum_dict_th8_3_4

unfitted_spectrum_dict_th8_arr[2][2] = unfitted_spectrum_dict_th8_3_3

unfitted_spectrum_dict_th8_arr[2][1] = unfitted_spectrum_dict_th8_3_2

unfitted_spectrum_dict_th8_arr[2][0] = unfitted_spectrum_dict_th8_3_1

unfitted_spectrum_dict_th8_arr[1][4] = unfitted_spectrum_dict_th8_2_5

unfitted_spectrum_dict_th8_arr[1][3] = unfitted_spectrum_dict_th8_2_4

unfitted_spectrum_dict_th8_arr[1][2] = unfitted_spectrum_dict_th8_2_3

unfitted_spectrum_dict_th8_arr[1][1] = unfitted_spectrum_dict_th8_2_2

unfitted_spectrum_dict_th8_arr[1][0] = unfitted_spectrum_dict_th8_2_1

unfitted_spectrum_dict_th8_arr[0][4] = unfitted_spectrum_dict_th8_1_5

unfitted_spectrum_dict_th8_arr[0][3] = unfitted_spectrum_dict_th8_1_4

unfitted_spectrum_dict_th8_arr[0][2] = unfitted_spectrum_dict_th8_1_3

unfitted_spectrum_dict_th8_arr[0][1] = unfitted_spectrum_dict_th8_1_2

unfitted_spectrum_dict_th8_arr[0][0] = unfitted_spectrum_dict_th8_1_1

# %%
fitted_spectrum_dict_th1_arr = [[0 for x in range(5)] for y in range(5)]

fitted_spectrum_dict_th1_arr[4][4] = fitted_spectrum_dict_th1_5_5

fitted_spectrum_dict_th1_arr[4][3] = fitted_spectrum_dict_th1_5_4

fitted_spectrum_dict_th1_arr[4][2] = fitted_spectrum_dict_th1_5_3

fitted_spectrum_dict_th1_arr[4][1] = fitted_spectrum_dict_th1_5_2

fitted_spectrum_dict_th1_arr[4][0] = fitted_spectrum_dict_th1_5_1

fitted_spectrum_dict_th1_arr[3][4] = fitted_spectrum_dict_th1_4_5

fitted_spectrum_dict_th1_arr[3][3] = fitted_spectrum_dict_th1_4_4

fitted_spectrum_dict_th1_arr[3][2] = fitted_spectrum_dict_th1_4_3

fitted_spectrum_dict_th1_arr[3][1] = fitted_spectrum_dict_th1_4_2

fitted_spectrum_dict_th1_arr[3][0] = fitted_spectrum_dict_th1_4_1

fitted_spectrum_dict_th1_arr[2][4] = fitted_spectrum_dict_th1_3_5

fitted_spectrum_dict_th1_arr[2][3] = fitted_spectrum_dict_th1_3_4

fitted_spectrum_dict_th1_arr[2][2] = fitted_spectrum_dict_th1_3_3

fitted_spectrum_dict_th1_arr[2][1] = fitted_spectrum_dict_th1_3_2

fitted_spectrum_dict_th1_arr[2][0] = fitted_spectrum_dict_th1_3_1

fitted_spectrum_dict_th1_arr[1][4] = fitted_spectrum_dict_th1_2_5

fitted_spectrum_dict_th1_arr[1][3] = fitted_spectrum_dict_th1_2_4

fitted_spectrum_dict_th1_arr[1][2] = fitted_spectrum_dict_th1_2_3

fitted_spectrum_dict_th1_arr[1][1] = fitted_spectrum_dict_th1_2_2

fitted_spectrum_dict_th1_arr[1][0] = fitted_spectrum_dict_th1_2_1

fitted_spectrum_dict_th1_arr[0][4] = fitted_spectrum_dict_th1_1_5

fitted_spectrum_dict_th1_arr[0][3] = fitted_spectrum_dict_th1_1_4

fitted_spectrum_dict_th1_arr[0][2] = fitted_spectrum_dict_th1_1_3

fitted_spectrum_dict_th1_arr[0][1] = fitted_spectrum_dict_th1_1_2

fitted_spectrum_dict_th1_arr[0][0] = fitted_spectrum_dict_th1_1_1

# %%
fitted_spectrum_dict_th3_arr = [[0 for x in range(5)] for y in range(5)]

fitted_spectrum_dict_th3_arr[4][4] = fitted_spectrum_dict_th3_5_5

fitted_spectrum_dict_th3_arr[4][3] = fitted_spectrum_dict_th3_5_4

fitted_spectrum_dict_th3_arr[4][2] = fitted_spectrum_dict_th3_5_3

fitted_spectrum_dict_th3_arr[4][1] = fitted_spectrum_dict_th3_5_2

fitted_spectrum_dict_th3_arr[4][0] = fitted_spectrum_dict_th3_5_1

fitted_spectrum_dict_th3_arr[3][4] = fitted_spectrum_dict_th3_4_5

fitted_spectrum_dict_th3_arr[3][3] = fitted_spectrum_dict_th3_4_4

fitted_spectrum_dict_th3_arr[3][2] = fitted_spectrum_dict_th3_4_3

fitted_spectrum_dict_th3_arr[3][1] = fitted_spectrum_dict_th3_4_2

fitted_spectrum_dict_th3_arr[3][0] = fitted_spectrum_dict_th3_4_1

fitted_spectrum_dict_th3_arr[2][4] = fitted_spectrum_dict_th3_3_5

fitted_spectrum_dict_th3_arr[2][3] = fitted_spectrum_dict_th3_3_4

fitted_spectrum_dict_th3_arr[2][2] = fitted_spectrum_dict_th3_3_3

fitted_spectrum_dict_th3_arr[2][1] = fitted_spectrum_dict_th3_3_2

fitted_spectrum_dict_th3_arr[2][0] = fitted_spectrum_dict_th3_3_1

fitted_spectrum_dict_th3_arr[1][4] = fitted_spectrum_dict_th3_2_5

fitted_spectrum_dict_th3_arr[1][3] = fitted_spectrum_dict_th3_2_4

fitted_spectrum_dict_th3_arr[1][2] = fitted_spectrum_dict_th3_2_3

fitted_spectrum_dict_th3_arr[1][1] = fitted_spectrum_dict_th3_2_2

fitted_spectrum_dict_th3_arr[1][0] = fitted_spectrum_dict_th3_2_1

fitted_spectrum_dict_th3_arr[0][4] = fitted_spectrum_dict_th3_1_5

fitted_spectrum_dict_th3_arr[0][3] = fitted_spectrum_dict_th3_1_4

fitted_spectrum_dict_th3_arr[0][2] = fitted_spectrum_dict_th3_1_3

fitted_spectrum_dict_th3_arr[0][1] = fitted_spectrum_dict_th3_1_2

fitted_spectrum_dict_th3_arr[0][0] = fitted_spectrum_dict_th3_1_1

# %%
fitted_spectrum_dict_th5_arr = [[0 for x in range(5)] for y in range(5)]

fitted_spectrum_dict_th5_arr[4][4] = fitted_spectrum_dict_th5_5_5

fitted_spectrum_dict_th5_arr[4][3] = fitted_spectrum_dict_th5_5_4

fitted_spectrum_dict_th5_arr[4][2] = fitted_spectrum_dict_th5_5_3

fitted_spectrum_dict_th5_arr[4][1] = fitted_spectrum_dict_th5_5_2

fitted_spectrum_dict_th5_arr[4][0] = fitted_spectrum_dict_th5_5_1

fitted_spectrum_dict_th5_arr[3][4] = fitted_spectrum_dict_th5_4_5

fitted_spectrum_dict_th5_arr[3][3] = fitted_spectrum_dict_th5_4_4

fitted_spectrum_dict_th5_arr[3][2] = fitted_spectrum_dict_th5_4_3

fitted_spectrum_dict_th5_arr[3][1] = fitted_spectrum_dict_th5_4_2

fitted_spectrum_dict_th5_arr[3][0] = fitted_spectrum_dict_th5_4_1

fitted_spectrum_dict_th5_arr[2][4] = fitted_spectrum_dict_th5_3_5

fitted_spectrum_dict_th5_arr[2][3] = fitted_spectrum_dict_th5_3_4

fitted_spectrum_dict_th5_arr[2][2] = fitted_spectrum_dict_th5_3_3

fitted_spectrum_dict_th5_arr[2][1] = fitted_spectrum_dict_th5_3_2

fitted_spectrum_dict_th5_arr[2][0] = fitted_spectrum_dict_th5_3_1

fitted_spectrum_dict_th5_arr[1][4] = fitted_spectrum_dict_th5_2_5

fitted_spectrum_dict_th5_arr[1][3] = fitted_spectrum_dict_th5_2_4

fitted_spectrum_dict_th5_arr[1][2] = fitted_spectrum_dict_th5_2_3

fitted_spectrum_dict_th5_arr[1][1] = fitted_spectrum_dict_th5_2_2

fitted_spectrum_dict_th5_arr[1][0] = fitted_spectrum_dict_th5_2_1

fitted_spectrum_dict_th5_arr[0][4] = fitted_spectrum_dict_th5_1_5

fitted_spectrum_dict_th5_arr[0][3] = fitted_spectrum_dict_th5_1_4

fitted_spectrum_dict_th5_arr[0][2] = fitted_spectrum_dict_th5_1_3

fitted_spectrum_dict_th5_arr[0][1] = fitted_spectrum_dict_th5_1_2

fitted_spectrum_dict_th5_arr[0][0] = fitted_spectrum_dict_th5_1_1

# %%
fitted_spectrum_dict_th8_arr = [[0 for x in range(5)] for y in range(5)]

fitted_spectrum_dict_th8_arr[4][4] = fitted_spectrum_dict_th8_5_5

fitted_spectrum_dict_th8_arr[4][3] = fitted_spectrum_dict_th8_5_4

fitted_spectrum_dict_th8_arr[4][2] = fitted_spectrum_dict_th8_5_3

fitted_spectrum_dict_th8_arr[4][1] = fitted_spectrum_dict_th8_5_2

fitted_spectrum_dict_th8_arr[4][0] = fitted_spectrum_dict_th8_5_1

fitted_spectrum_dict_th8_arr[3][4] = fitted_spectrum_dict_th8_4_5

fitted_spectrum_dict_th8_arr[3][3] = fitted_spectrum_dict_th8_4_4

fitted_spectrum_dict_th8_arr[3][2] = fitted_spectrum_dict_th8_4_3

fitted_spectrum_dict_th8_arr[3][1] = fitted_spectrum_dict_th8_4_2

fitted_spectrum_dict_th8_arr[3][0] = fitted_spectrum_dict_th8_4_1

fitted_spectrum_dict_th8_arr[2][4] = fitted_spectrum_dict_th8_3_5

fitted_spectrum_dict_th8_arr[2][3] = fitted_spectrum_dict_th8_3_4

fitted_spectrum_dict_th8_arr[2][2] = fitted_spectrum_dict_th8_3_3

fitted_spectrum_dict_th8_arr[2][1] = fitted_spectrum_dict_th8_3_2

fitted_spectrum_dict_th8_arr[2][0] = fitted_spectrum_dict_th8_3_1

fitted_spectrum_dict_th8_arr[1][4] = fitted_spectrum_dict_th8_2_5

fitted_spectrum_dict_th8_arr[1][3] = fitted_spectrum_dict_th8_2_4

fitted_spectrum_dict_th8_arr[1][2] = fitted_spectrum_dict_th8_2_3

fitted_spectrum_dict_th8_arr[1][1] = fitted_spectrum_dict_th8_2_2

fitted_spectrum_dict_th8_arr[1][0] = fitted_spectrum_dict_th8_2_1

fitted_spectrum_dict_th8_arr[0][4] = fitted_spectrum_dict_th8_1_5

fitted_spectrum_dict_th8_arr[0][3] = fitted_spectrum_dict_th8_1_4

fitted_spectrum_dict_th8_arr[0][2] = fitted_spectrum_dict_th8_1_3

fitted_spectrum_dict_th8_arr[0][1] = fitted_spectrum_dict_th8_1_2

fitted_spectrum_dict_th8_arr[0][0] = fitted_spectrum_dict_th8_1_1

# %%
photon_num_min=10

def luminosity(spectrum_dict):
    lum = np.trapz(spectrum_dict['spectrum'][np.where(spectrum_dict['ph_num']>photon_num_min)[0]],
    spectrum_dict['energy_bin_center'][np.where(spectrum_dict['ph_num']>photon_num_min)[0]])
    return lum

def zeta_lum(spectrum_dict, spectrum_dict_high_res):
    lum = luminosity(spectrum_dict)
    lum_high_res = luminosity(spectrum_dict_high_res)
    zeta = (lum - lum_high_res) / lum_high_res
    return zeta

def zeta_e_pk(spectrum_dict, spectrum_dict_high_res):
    peak_e, peak_e_err = pm.calc_epk_error(spectrum_dict['fit']['alpha'], 
                                        spectrum_dict['fit']['break_energy'],\
                                        alpha_error=spectrum_dict['fit_errors']['alpha_errors'],\
                                        break_energy_error=
                                           spectrum_dict['fit_errors']['break_energy_errors'])
    peak_e_high_res, peak_e_err_high_res = pm.calc_epk_error(spectrum_dict_high_res['fit']['alpha'], 
                                        spectrum_dict_high_res['fit']['break_energy'],\
                                        alpha_error=spectrum_dict_high_res['fit_errors']['alpha_errors'],\
                                        break_energy_error=
                                           spectrum_dict_high_res['fit_errors']['break_energy_errors'])
    zeta = (peak_e - peak_e_high_res) / peak_e_high_res
    return zeta

def zeta_beta(spectrum_dict, spectrum_dict_high_res):
    beta = spectrum_dict['fit']['beta']
    beta_high_res = spectrum_dict_high_res['fit']['beta']
    zeta = (beta - beta_high_res) / beta_high_res
    return zeta

def zeta_alpha(spectrum_dict, spectrum_dict_high_res):
    alpha = spectrum_dict['fit']['alpha']
    alpha_high_res = spectrum_dict_high_res['fit']['alpha']
    zeta = (alpha - alpha_high_res) / alpha_high_res
    return zeta

# %%
z_lum_th1_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th3_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th5_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th8_matrix = [[0 for x in range(5)] for y in range(5)]


for i in range(5):
    for j in range(5):
        z_lum_th1_matrix[i][j]=zeta_lum(unfitted_spectrum_dict_th1_arr[i][j],unfitted_spectrum_dict_th1_arr[4][4])
        
#        z_lum_th3_matrix[i][j]=zeta_lum(unfitted_spectrum_dict_th3_arr[i][j],unfitted_spectrum_dict_th3_arr[4][4])
        
#        z_lum_th5_matrix[i][j]=zeta_lum(unfitted_spectrum_dict_th5_arr[i][j],unfitted_spectrum_dict_th5_arr[4][4])
        
#        z_lum_th8_matrix[i][j]=zeta_lum(unfitted_spectrum_dict_th8_arr[i][j],unfitted_spectrum_dict_th8_arr[4][4])

# %%
z_e_pk_th1_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th3_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th5_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th8_matrix = [[0 for x in range(5)] for y in range(5)]


for i in range(5):
    for j in range(5):
        z_e_pk_th1_matrix[i][j] = zeta_e_pk(fitted_spectrum_dict_th1_arr[i][j],fitted_spectrum_dict_th1_arr[4][4])
        
#        z_e_pk_th3_matrix[i][j] = zeta_e_pk(fitted_spectrum_dict_th3_arr[i][j],fitted_spectrum_dict_th3_arr[4][4])
        
#        z_e_pk_th5_matrix[i][j] = zeta_e_pk(fitted_spectrum_dict_th5_arr[i][j],fitted_spectrum_dict_th5_arr[4][4])
        
#        z_e_pk_th8_matrix[i][j] = zeta_e_pk(fitted_spectrum_dict_th8_arr[i][j],fitted_spectrum_dict_th8_arr[4][4])

# %%
z_alpha_th1_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th3_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th5_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th8_matrix = [[0 for x in range(5)] for y in range(5)]


for i in range(5):
    for j in range(5):
        z_alpha_th1_matrix[i][j]=zeta_alpha(fitted_spectrum_dict_th1_arr[i][j],fitted_spectrum_dict_th1_arr[4][4])
        
#        z_alpha_th3_matrix[i][j]=zeta_alpha(fitted_spectrum_dict_th3_arr[i][j],fitted_spectrum_dict_th3_arr[4][4])
        
#        z_alpha_th5_matrix[i][j]=zeta_alpha(fitted_spectrum_dict_th5_arr[i][j],fitted_spectrum_dict_th5_arr[4][4])
        
#        z_alpha_th8_matrix[i][j]=zeta_alpha(fitted_spectrum_dict_th8_arr[i][j],fitted_spectrum_dict_th8_arr[4][4])

# %%
z_beta_th1_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th3_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th5_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th8_matrix = [[0 for x in range(5)] for y in range(5)]


for i in range(5):
    for j in range(5):
        z_beta_th1_matrix[i][j]=zeta_beta(fitted_spectrum_dict_th1_arr[i][j],fitted_spectrum_dict_th1_arr[4][4])
        
#        z_beta_th3_matrix[i][j]=zeta_beta(fitted_spectrum_dict_th3_arr[i][j],fitted_spectrum_dict_th3_arr[4][4])
        
#        z_beta_th5_matrix[i][j]=zeta_beta(fitted_spectrum_dict_th5_arr[i][j],fitted_spectrum_dict_th5_arr[4][4])
        
#        z_beta_th8_matrix[i][j]=zeta_beta(fitted_spectrum_dict_th8_arr[i][j],fitted_spectrum_dict_th8_arr[4][4])

# %%
res_levs = ['1','2','3','4','5']

fps = ['0.3125fps','0.625fps','1.25fps','2.5fps','5fps']

# %%
z_lum_th1_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th3_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th5_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_lum_th8_abs_matrix = [[0 for x in range(5)] for y in range(5)]

for i in range(5):
    for j in range(5):
        z_lum_th1_abs_matrix[i][j] = np.abs(z_lum_th1_matrix[i][j])
        
#        z_lum_th3_abs_matrix[i][j] = np.abs(z_lum_th3_matrix[i][j])
        
#        z_lum_th5_abs_matrix[i][j] = np.abs(z_lum_th5_matrix[i][j])
        
#        z_lum_th8_abs_matrix[i][j] = np.abs(z_lum_th8_matrix[i][j])

# %%
z_e_pk_th1_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th3_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th5_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_e_pk_th8_abs_matrix = [[0 for x in range(5)] for y in range(5)]

for i in range(5):
    for j in range(5):
        z_e_pk_th1_abs_matrix[i][j] = np.abs(z_e_pk_th1_matrix[i][j])
        
#        z_e_pk_th3_abs_matrix[i][j] = np.abs(z_e_pk_th3_matrix[i][j])
        
#        z_e_pk_th5_abs_matrix[i][j] = np.abs(z_e_pk_th5_matrix[i][j])
        
#        z_e_pk_th8_abs_matrix[i][j] = np.abs(z_e_pk_th8_matrix[i][j])

# %%
z_alpha_th1_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th3_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th5_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_alpha_th8_abs_matrix = [[0 for x in range(5)] for y in range(5)]

for i in range(5):
    for j in range(5):
        z_alpha_th1_abs_matrix[i][j] = np.abs(z_alpha_th1_matrix[i][j])
        
#        z_alpha_th3_abs_matrix[i][j] = np.abs(z_alpha_th3_matrix[i][j])
        
#        z_alpha_th5_abs_matrix[i][j] = np.abs(z_alpha_th5_matrix[i][j])
        
#        z_alpha_th8_abs_matrix[i][j] = np.abs(z_alpha_th8_matrix[i][j])

# %%
z_beta_th1_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th3_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th5_abs_matrix = [[0 for x in range(5)] for y in range(5)]

#z_beta_th8_abs_matrix = [[0 for x in range(5)] for y in range(5)]

for i in range(5):
    for j in range(5):
        z_beta_th1_abs_matrix[i][j] = np.abs(z_beta_th1_matrix[i][j])
        
#        z_beta_th3_abs_matrix[i][j] = np.abs(z_beta_th3_matrix[i][j])
        
#        z_beta_th5_abs_matrix[i][j] = np.abs(z_beta_th5_matrix[i][j])
        
#        z_beta_th8_abs_matrix[i][j] = np.abs(z_beta_th8_matrix[i][j])

# %%
import matplotlib as mpl

x_list = ['1','2','3','4','5']

x_ticks = [0,1,2,3,4]

y_list = ['0.3125','0.625','1.25','2.5','5']

plt.rcParams.update({'font.size': 20})

mpl.rcParams.update(mpl.rcParamsDefault)

from matplotlib import rc

font_size = 12 # Adjust as appropriate.


fig, ax = plt.subplots(2,2)

#fig.set_figwidth(12)
#fig.set_figheight(12)

ax[0][0].imshow(z_lum_th1_abs_matrix)
ax[0][1].imshow(z_e_pk_th1_abs_matrix)
ax[1][0].imshow(z_alpha_th1_abs_matrix)
ax[1][1].imshow(z_beta_th1_abs_matrix)

mapp00 = ax[0][0].imshow(z_lum_th1_abs_matrix, cmap = 'Blues')
mapp01 = ax[0][1].imshow(z_e_pk_th1_abs_matrix, cmap = 'Blues')
mapp10 = ax[1][0].imshow(z_alpha_th1_abs_matrix, cmap = 'Blues')
mapp11 = ax[1][1].imshow(z_beta_th1_abs_matrix, cmap = 'Blues')

ax[0][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[0][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

ax[0][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[0][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)

#plt.ylabel('Temporal Levels (fps)', fontsize = 20)
#plt.xlabel('Spatial Refinement Levels', fontsize = 20)

ax[0][0].xaxis.set_label_position('top')

cb00 = plt.colorbar(mappable = mapp00, ax = ax[0][0])

cb01 = plt.colorbar(mappable = mapp01, ax = ax[0][1])

cb10 = plt.colorbar(mappable = mapp10, ax = ax[1][0])

cb11 = plt.colorbar(mappable = mapp11, ax = ax[1][1])

#plt.suptitle(r'EM properties at $\theta_{obs}=1$')

cb00.ax.tick_params(labelsize=font_size)
cb00.set_label(r'$\zeta_{L_{iso}}$', size = font_size)

cb01.ax.tick_params(labelsize=font_size)
cb01.set_label(r'$\zeta_{E_{pk}}$', size = font_size)

cb10.ax.tick_params(labelsize=font_size)
cb10.set_label(r'$\zeta_{\alpha}$', size = font_size)

cb11.ax.tick_params(labelsize=font_size)
cb11.set_label(r'$\zeta_{\beta}$', size = font_size)

ax[0][0].annotate('(a)', xy = (-2,-1), size = font_size, annotation_clip=False)
ax[0][1].annotate('(b)', xy = (-2,-1), size = font_size, annotation_clip=False)
ax[1][0].annotate('(c)', xy = (-2,-1), size = font_size, annotation_clip=False)
ax[1][1].annotate('(d)', xy = (-2,-1), size = font_size, annotation_clip=False)

for i in range(len(res_levs)):
    for j in range(len(fps)):
        text00 = ax[0][0].text(i, j, round(float(z_lum_th1_abs_matrix[j][i]),2),
                       ha="center", va="center", color="k", size=7)
        text01 = ax[0][1].text(i, j, round(float(z_e_pk_th1_abs_matrix[j][i]),2),
                       ha="center", va="center", color="k", size=7)
        text10 = ax[1][0].text(i, j, round(float(z_alpha_th1_abs_matrix[j][i]),2),
                       ha="center", va="center", color="k", size=7)
        text11 = ax[1][1].text(i, j, round(float(z_beta_th1_abs_matrix[j][i]),2),
                       ha="center", va="center", color="k", size=7)
        
        
fig.suptitle('Spatial Refinement Levels', size = font_size)
fig.supylabel('Temporal Refinement Levels (fps)', size = font_size)

plt.tight_layout()
plt.savefig('zeta_th1_all.pdf',dpi=600, bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
font_size = 10 # Adjust as appropriate.


fig, ax = plt.subplots(2,2)

ax[0][0].imshow(z_lum_th3_abs_matrix)
ax[1][0].imshow(z_e_pk_th3_abs_matrix)
ax[0][1].imshow(z_alpha_th3_abs_matrix)
ax[1][1].imshow(z_beta_th3_abs_matrix)

mapp00 = ax[0][0].imshow(z_lum_th3_abs_matrix)
mapp10 = ax[1][0].imshow(z_e_pk_th3_abs_matrix)
mapp01 = ax[0][1].imshow(z_alpha_th3_abs_matrix)
mapp11 = ax[1][1].imshow(z_beta_th3_abs_matrix)

ax[0][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[0][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

ax[0][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[0][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)

#plt.ylabel('Temporal Levels (fps)', fontsize = 20)
#plt.xlabel('Spatial Refinement Levels', fontsize = 20)

ax[0][0].xaxis.set_label_position('top')

cb00 = plt.colorbar(mappable = mapp00, ax = ax[0][0])

cb01 = plt.colorbar(mappable = mapp01, ax = ax[0][1])

cb10 = plt.colorbar(mappable = mapp10, ax = ax[1][0])

cb11 = plt.colorbar(mappable = mapp11, ax = ax[1][1])

plt.suptitle(r'EM properties at $\theta_{obs}=3$')

cb00.ax.tick_params(labelsize=font_size)
cb00.set_label(r'$\zeta_{L_{iso}}$', size = font_size)

cb10.ax.tick_params(labelsize=font_size)
cb10.set_label(r'$\zeta_{E_{pk}}$', size = font_size)

cb01.ax.tick_params(labelsize=font_size)
cb01.set_label(r'$\zeta_{\alpha}$', size = font_size)

cb11.ax.tick_params(labelsize=font_size)
cb11.set_label(r'$\zeta_{\beta}$', size = font_size)

plt.tight_layout()
plt.savefig('zeta_th3.pdf',dpi=600, bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
font_size = 10 # Adjust as appropriate.


fig, ax = plt.subplots(2,2)

ax[0][0].imshow(z_lum_th5_abs_matrix)
ax[1][0].imshow(z_e_pk_th5_abs_matrix)
ax[0][1].imshow(z_alpha_th5_abs_matrix)
ax[1][1].imshow(z_beta_th5_abs_matrix)

mapp00 = ax[0][0].imshow(z_lum_th5_abs_matrix)
mapp10 = ax[1][0].imshow(z_e_pk_th5_abs_matrix)
mapp01 = ax[0][1].imshow(z_alpha_th5_abs_matrix)
mapp11 = ax[1][1].imshow(z_beta_th5_abs_matrix)

ax[0][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[0][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

ax[0][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[0][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)

#plt.ylabel('Temporal Levels (fps)', fontsize = 20)
#plt.xlabel('Spatial Refinement Levels', fontsize = 20)

ax[0][0].xaxis.set_label_position('top')

cb00 = plt.colorbar(mappable = mapp00, ax = ax[0][0])

cb01 = plt.colorbar(mappable = mapp01, ax = ax[0][1])

cb10 = plt.colorbar(mappable = mapp10, ax = ax[1][0])

cb11 = plt.colorbar(mappable = mapp11, ax = ax[1][1])

plt.suptitle(r'EM properties at $\theta_{obs}=5$')

cb00.ax.tick_params(labelsize=font_size)
cb00.set_label(r'$\zeta_{L_{iso}}$', size = font_size)

cb10.ax.tick_params(labelsize=font_size)
cb10.set_label(r'$\zeta_{E_{pk}}$', size = font_size)

cb01.ax.tick_params(labelsize=font_size)
cb01.set_label(r'$\zeta_{\alpha}$', size = font_size)

cb11.ax.tick_params(labelsize=font_size)
cb11.set_label(r'$\zeta_{\beta}$', size = font_size)

plt.tight_layout()
plt.savefig('zeta_th5.pdf',dpi=600, bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
font_size = 10 # Adjust as appropriate.


fig, ax = plt.subplots(2,2)

ax[0][0].imshow(z_lum_th8_abs_matrix)
ax[1][0].imshow(z_e_pk_th8_abs_matrix)
ax[0][1].imshow(z_alpha_th8_abs_matrix)
ax[1][1].imshow(z_beta_th8_abs_matrix)

mapp00 = ax[0][0].imshow(z_lum_th8_abs_matrix)
mapp10 = ax[1][0].imshow(z_e_pk_th8_abs_matrix)
mapp01 = ax[0][1].imshow(z_alpha_th8_abs_matrix)
mapp11 = ax[1][1].imshow(z_beta_th8_abs_matrix)

ax[0][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][0].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[0][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[1][1].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

ax[0][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][0].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][0].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[0][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[0][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)
ax[1][1].set_xticks(ticks = x_ticks, labels = x_list, fontsize = font_size)
ax[1][1].set_yticks(ticks = x_ticks, labels = y_list, fontsize = font_size)

#plt.ylabel('Temporal Levels (fps)', fontsize = 20)
#plt.xlabel('Spatial Refinement Levels', fontsize = 20)

ax[0][0].xaxis.set_label_position('top')

cb00 = plt.colorbar(mappable = mapp00, ax = ax[0][0])

cb01 = plt.colorbar(mappable = mapp01, ax = ax[0][1])

cb10 = plt.colorbar(mappable = mapp10, ax = ax[1][0])

cb11 = plt.colorbar(mappable = mapp11, ax = ax[1][1])

plt.suptitle(r'EM properties at $\theta_{obs}=8$')

cb00.ax.tick_params(labelsize=font_size)
cb00.set_label(r'$\zeta_{L_{iso}}$', size = font_size)

cb10.ax.tick_params(labelsize=font_size)
cb10.set_label(r'$\zeta_{E_{pk}}$', size = font_size)

cb01.ax.tick_params(labelsize=font_size)
cb01.set_label(r'$\zeta_{\alpha}$', size = font_size)

cb11.ax.tick_params(labelsize=font_size)
cb11.set_label(r'$\zeta_{\beta}$', size = font_size)

plt.tight_layout()
plt.savefig('zeta_th8.pdf',dpi=600, bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
z_alpha_th1_abs_matrix[3][1]
# Out:
# 0.7976253963981013

# %%
fitted_spectrum_dict_th1_4_4['energy_bin_center']
# Out:
# <Quantity [1.12201845e-07, 1.41253754e-07, 1.77827941e-07, 2.23872114e-07,
#            2.81838293e-07, 3.54813389e-07, 4.46683592e-07, 5.62341325e-07,
#            7.07945784e-07, 8.91250938e-07, 1.12201845e-06, 1.41253754e-06,
#            1.77827941e-06, 2.23872114e-06, 2.81838293e-06, 3.54813389e-06,
#            4.46683592e-06, 5.62341325e-06, 7.07945784e-06, 8.91250938e-06,
#            1.12201845e-05, 1.41253754e-05, 1.77827941e-05, 2.23872114e-05,
#            2.81838293e-05, 3.54813389e-05, 4.46683592e-05, 5.62341325e-05,
#            7.07945784e-05, 8.91250938e-05, 1.12201845e-04, 1.41253754e-04,
#            1.77827941e-04, 2.23872114e-04, 2.81838293e-04, 3.54813389e-04,
#            4.46683592e-04, 5.62341325e-04, 7.07945784e-04, 8.91250938e-04,
#            1.12201845e-03, 1.41253754e-03, 1.77827941e-03, 2.23872114e-03,
#            2.81838293e-03, 3.54813389e-03, 4.46683592e-03, 5.62341325e-03,
# ...

# %%
plt.scatter(fitted_spectrum_dict_th1_4_4['energy_bin_center'],fitted_spectrum_dict_th1_4_4['ph_num'])
plt.xscale('log')
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def band_function(energies, alpha, beta, break_energy, normalization, energy_unit=unit.keV):
	"""
	Calculates the Band model for a range of energies using specified alpha, break energy, and normalization parameters

	:param energies: Array of energies at which the Band spectrum should be calculated
	:param alpha: number which denotes the low energy slope of the Band function
	:param beta: number which denotes the high energy slope of the Band function
	:param break_energy: number which dentoes the energy where the powerlaw changes slopes
	:param normalization: Number which represents the total normalization of the returned spectrum
	:param energy_unit: Default of keV or astropy unit that denotes the units of the
	:return: array of the returned Band model values at the specified energies
	"""
	try:
		energies=energies.value
	except AttributeError:
		energies = energies

	try:
		break_energy=break_energy.value
	except AttributeError:
		break_energy = break_energy

	try:
		normalization=normalization.value
	except AttributeError:
		normalization = normalization


	model=np.empty(energies.size)
	kk=np.where(energies<((alpha-beta)*break_energy))
	if kk[0].size>0:
		model[kk]=energies[kk]**alpha*np.exp(-energies[kk]/break_energy)
	kk=np.where(energies>=((alpha-beta)*break_energy))
	if kk[0].size>0:
		model[kk]=((alpha-beta)*break_energy)**(alpha-beta)*energies[kk]**(beta)*np.exp(beta-alpha)
	model=model/np.trapz(model,x=energies)*normalization

	return model

photon_num_min=10


plt.rcParams.update({'font.size': 20})

label_size = 20
mpl.rcParams['ytick.labelsize'] = label_size 


f, axarr = plt.subplots(2, sharex = True)
axarr_spex = axarr

f.set_figwidth(12)
f.set_figheight(18)

colors=['b','r','b','c','g']

idx = np.where(fitted_spectrum_dict_th1_4_4['ph_num']>photon_num_min)[0]

axarr_spex[0].set_xlabel(r'E' + ' ('+fitted_spectrum_dict_th1_4_4['energy_bin_center'].unit.to_string('latex_inline')+')', 
                                  fontsize=14)
axarr_spex[0].set_ylabel(r'L$_E$ ('+fitted_spectrum_dict_th1_4_4['spectrum'][idx].unit.to_string('latex_inline')+')', 
                                  fontsize=20)

axarr_spex[0].loglog(fitted_spectrum_dict_th1_4_4['energy_bin_center'][idx], 
                  fitted_spectrum_dict_th1_4_4['spectrum'][idx], colors[4]+".")
axarr_spex[0].errorbar(fitted_spectrum_dict_th1_4_4['energy_bin_center'][idx], 
                    fitted_spectrum_dict_th1_4_4['spectrum'][idx],\
                    yerr=fitted_spectrum_dict_th1_4_4['spectrum_errors'][idx], 
                    color=colors[0], marker='o', ls='None', 
                    markersize=10, label='2.5fps level 4')
band_in_energy_range = band_function(fitted_spectrum_dict_th1_4_4['energy_bin_center'][idx], fitted_spectrum_dict_th1_4_4['fit']['alpha'], fitted_spectrum_dict_th1_4_4['fit']['beta'], fitted_spectrum_dict_th1_4_4['fit']['break_energy'], fitted_spectrum_dict_th1_4_4['fit']['normalization'])
axarr_spex[0].plot(fitted_spectrum_dict_th1_4_4['energy_bin_center'][idx], band_in_energy_range, color='k', label='Fitted Band', ls='solid', lw=3, zorder=3)
        #full_band = Band(nucen_all, best[0], best[1], best[2], best[
        #	3])  # this is for the extrapolated portion below energy range keV, also normalize it so its continuous with other plotted band function >energy range
        #full_band = full_band * band_in_energy_range[-1] / full_band[-1]
        #axarr_spex.plot(nucen_all[nucen_all <= fermi_gbm_e_min], full_band[nucen_all <= fermi_gbm_e_min], 'k--', lw=3,
        #				label='Extrapolated Band', zorder=3)

axarr_spex[0].annotate(r'$\alpha$' + '=' + np.str(fitted_spectrum_dict_th1_4_4['fit']['alpha']).split('.')[0] + '.' + np.str(fitted_spectrum_dict_th1_4_4['fit']['alpha']).split('.')[1][0] +
                        '\n' + r'$\beta$' + '=' + np.str(fitted_spectrum_dict_th1_4_4['fit']['beta']).split('.')[0] + '.' +
                        np.str(fitted_spectrum_dict_th1_4_4['fit']['beta']).split('.')[1][0] + '\n' + r'E$_{\mathrm{o}}$' + '=' +
                        np.str(fitted_spectrum_dict_th1_4_4['fit']['break_energy']).split('.')[0] + '.' + np.str(fitted_spectrum_dict_th1_4_4['fit']['break_energy']).split('.')[1][0]\
                        + ' '+fitted_spectrum_dict_th1_4_4['energy_bin_center'].unit.to_string('latex_inline'), xy=(0, 0),
                        xycoords='axes fraction', fontsize=18, xytext=(10, 10),
                        textcoords='offset points', ha='left', va='bottom')

axarr_spex[0].legend(loc = 'lower center')
    
axarr_spex[1].set_xlim(10**-2,10**5)

#axarr_spex[2].set_ylim(9e44,6e48)

axarr_spex[1].scatter(fitted_spectrum_dict_th1_4_4['energy_bin_center'],fitted_spectrum_dict_th1_4_4['ph_num'])
axarr_spex[1].set_yscale('log')
plt.tight_layout()
plt.savefig('spectrum_problem_2.5fps_lev4.pdf' , dpi=600)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <ipython-input-53-b59fbf24c03f>:79: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   axarr_spex[0].annotate(r'$\alpha$' + '=' + np.str(fitted_spectrum_dict_th1_4_4['fit']['alpha']).split('.')[0] + '.' + np.str(fitted_spectrum_dict_th1_4_4['fit']['alpha']).split('.')[1][0] +
# <ipython-input-53-b59fbf24c03f>:80: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# ...

# %%
print(fitted_spectrum_dict_th1_4_4['fit'])
print(fitted_spectrum_dict_th1_4_4['fit_errors'])
# Out:
# {'alpha': 1.8033104198293126, 'beta': -1.5594077305644194, 'break_energy': <Quantity 9.64971985 keV>, 'normalization': 1.5770388074804007e+57}
# {'alpha_errors': 0.04111505980638052, 'beta_errors': 0.012280176340998433, 'break_energy_errors': <Quantity 0.40447323 keV>}
